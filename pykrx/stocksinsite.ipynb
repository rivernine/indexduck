# %% [markdown]
# https://github.com/sharebook-kr/pykrx

# %%
from pykrx import stock
# 티커리스트 조회
# input : 일자(미 입력 시 최근 영업일 DEFAULT)
#   - market: KOSPI(DEFAULT), KOSDAQ, KONEX, ALL
tickers = stock.get_market_ticker_list("20210830", market='KOSDAQ')
print(tickers)

# %%
# 종목이름 조회
# input : ticker
for ticker in stock.get_market_ticker_list():
  name = stock.get_market_ticker_name(ticker)
  print(name)

# %%
# 일자별 OHLCV 조회
# input : 시작일/종료일/티커/(Optional)(d/m/y)
df = stock.get_market_ohlcv_by_date("20210827", "20210830", "005930")
df.head(3)
# Out:
#                시가     고가     저가     종가       거래량
# 날짜
# 2021-08-27  74300  75000  73800  74300  15172748
# 2021-08-30  75400  75500  74200  74600  12686999

# %%
# 전체 종목 시세 조회
# input : 날짜
#   - market: KOSPI(DEFAULT), KOSDAQ, KONEX, ALL
df = stock.get_market_ohlcv_by_ticker("20210830")
print(df.head(3))
# Out:
#            시가     고가     저가     종가     거래량        거래대금   등락률
# 티커
# 095570   5850   5970   5770   5920   68587   399761400  2.07
# 006840  26350  27400  26100  27300   56037  1499906350  3.80
# 027410   6320   6410   6300   6360  232110  1477499330  2.09
# 935

# %%
# 종목별 DIV/BPS/PER/EPS 조회
# input : 날짜
#   - market: KOSPI(DEFAULT), KOSDAQ, KONEX, ALL
df = stock.get_market_fundamental_by_ticker("20210108")
df
# Out:
#           BPS        PER       PBR   EPS       DIV   DPS
# 티커
# 095570   6802   4.621094  0.669922   982  6.609375   300
# 006840  62448  11.687500  0.409912  2168  2.960938   750
# 027410  15699  17.453125  0.310059   281  2.240234   110
# 282330  36022  16.093750  3.910156  8763  1.910156  2700
# 138930  25415   3.509766  0.229980  1647  6.230469   360
# ...       ...        ...       ...   ...       ...   ...
# 069260  15970  14.351562  1.629883  1812  3.849609  1000
# 000540  10926   5.878906  0.270020   510  0.000000     0
# 000547      0   0.000000  0.000000     0  0.000000     0
# 000545      0   0.000000  0.000000     0  0.000000     0
# 003280    276   0.000000  0.930176     0  0.000000     0
#
# [895 rows x 6 columns]

# %%
# 일자별 DIV/BPS/PER/EPS 조회
# input : 시작날짜, 종료날짜, 종목
#  - freq: d/m/y
df = stock.get_market_fundamental_by_date("20210104", "20210108", "005930")
print(df.head(2))

# %%
# 일자별 거래대금 조회
# input : 시작날짜, 종료날짜, 종목
#   - on: 매수, 매도, 순매수(DEFAULT)
df = stock.get_market_trading_value_by_date("20210115", "20210122", "005930")
df
df.index[0]
# Out:
# Timestamp('2021-01-15 00:00:00')

# %%
# 일자별 거래량 조회
# input : 시작날짜, 종료날짜, 종목
#   - on: 매수, 매도, 순매수(DEFAULT)
df = stock.get_market_trading_volume_by_date("20210115", "20210122", "005930")
df
# Out:
#                기관합계    기타법인       개인    외국인합계  전체
# 날짜
# 2021-01-15 -5006115  288832  7485785 -2768502   0
# 2021-01-18   505669  262604   151228  -919501   0
# 2021-01-19  1139258  -34023 -2044543   939308   0
# 2021-01-20 -4157919  262408  4917655 -1022144   0
# 2021-01-21  -712099 -321732  2890389 -1856558   0
# 2021-01-22 -6384793   56478  9884815 -3556500   0

# %%
# 투자자별 거래대금 조회
# input : 시작날짜, 종료날짜, 종목
df = stock.get_market_trading_value_by_investor("20210115", "20210122", "005930")
# print(df)
# print(df.loc['개인', '매수'])
# print(df.loc['개인', '매도'])
# print(df.loc['개인', '순매수'])
df
# Out:
#                    매도              매수            순매수
# 투자자구분
# 금융투자    2580964135000   2309054317700  -271909817300
# 보험       153322228800     44505136200  -108817092600
# 투신       258073006600    150715203700  -107357802900
# 사모        65167773900     60862926800    -4304847100
# 은행         3369626100      4004806100      635180000
# 기타금융       3477393800      4877166100     1399772300
# 연기금 등   4242868457300   3442541806900  -800326650400
# 기관합계    7307242621500   6016561363500 -1290681258000
# 기타법인     133693205700    178684949600    44991743900
# 개인      6918846810800   8972911580500  2054064769700
# 외국인     2891788072484   2077977924484  -813810148000
# 기타외국인     15364164000     20799056400     5434892400
# 전체     17266934874484  17266934874484              0

# %%
# 투자자별 거래량 조회
# input : 시작날짜, 종료날짜, 종목
df = stock.get_market_trading_volume_by_investor("20210826", "20210826", "005930")
# print(df.loc['기관합계'])
# print(df.loc['기관합계'][0])
# print(df.loc['기관합계'][1])
df
# Out:
#              매도        매수      순매수
# 투자자구분
# 금융투자    1842774   1361611  -481163
# 보험        28340     19501    -8839
# 투신        71713     39198   -32515
# 사모        26427     23972    -2455
# 은행            0      8000     8000
# 기타금융      26591         0   -26591
# 연기금 등   7251929   7053998  -197931
# 기관합계    9247774   8506280  -741494
# 기타법인      45168    169923   124755
# 개인      3578936   5480229  1901293
# 외국인     3788399   2503018 -1285381
# 기타외국인     11217     12044      827
# 전체     16671494  16671494        0

# %%
# 투자자별 순매수 상위종목 조회
# input : 시작날짜, 종료날짜, 시장(KOSPI/KOSDAQ), 투자자(금융투자/보험/투신/사모/은행/기타금융/연기금/기관합계/기타법인/개인/외국인/기타외국인/전체)
df = stock.get_market_net_purchases_of_equities_by_ticker("20210115", "20210122", "KOSPI", "개인")
df
# Out:
#             종목명     매도거래량      매수거래량    순매수거래량         매도거래대금         매수거래대금  \
# 티커
# 005930     삼성전자  79567418  102852747  23285329  6918846810800  8972911580500
# 000270      기아차  44440252   49880626   5440374  3861283906400  4377698855000
# 005935    삼성전자우  15849762   20011325   4161563  1207133611400  1528694164400
# 051910     LG화학    709872     921975    212103   700823533000   908593419000
# 096770  SK이노베이션   4848359    5515777    667418  1298854139000  1478890602000
# ...         ...       ...        ...       ...            ...            ...
# 090430   아모레퍼시픽   1623553    1161213   -462340   369035759000   262552157500
# 035720      카카오   2681319    2404104   -277215  1205582480500  1077562119500
# 006400    삼성SDI   1544311    1333957   -210354  1156440902000   990487435000
# 285130    SK케미칼   2555085    2085241   -469844  1010511216500   823227903000
# 035420    NAVER   4644834    3449785  -1195049  1512026990000  1109562184000
#
#               순매수거래대금
# 티커
# 005930  2054064769700
# 000270   516414948600
# 005935   321560553000
# 051910   207769886000
# 096770   180036463000
# ...               ...
# 090430  -106483601500
# 035720  -128020361000
# 006400  -165953467000
# 285130  -187283313500
# 035420  -402464806000
#
# [906 rows x 7 columns]

# %%
# 종목별 시가총액 조회
# input : 날짜
df = stock.get_market_cap_by_ticker("20200625")
df
# Out:
#             종가             시가총액       거래량          거래대금       상장주식수
# 티커
# 005930   51900  309831714345000  18541624  970494909540  5969782550
# 000660   84300   61370599369500   3397112  287640892200   728002365
# 207940  815000   53924475000000    163339  133594217000    66165000
# 035420  269500   44268984952500   1196267  325381436500   164263395
# 068270  316000   42640845660000    918369  291688043500   134939385
# ...        ...              ...       ...           ...         ...
# 001529   30450       2732034900      2426      73806550       89722
# 238500     481       2252121846     10841       5711160     4682166
# 208890     999       2148669180       127        115157     2150820
# 267810    1150       1779050000      1300       1395000     1547000
# 224020     450       1215000000         2           900     2700000
#
# [2475 rows x 5 columns]

# %%
# ETF티커 조회
# input : 날짜
tickers = stock.get_etf_ticker_list("20200717")
print(tickers[:10])
# Out:
# ['292340', '159800', '285000', '287300', '287310', '290080', '284980', '287320', '287330', '252400']

# %%
# ETF이름 조회
# input: 티커
tickers = stock.get_etf_ticker_list("20021014")
for ticker in tickers:
  print(stock.get_etf_ticker_name(ticker))

# %%
# 일자별 ETF OHLCV 조회
# input : 시작날짜, 종료날짜, 종목
#   - d/m/y
df = stock.get_etf_ohlcv_by_date("20210104", "20210108", "292340")
type(df)
# print(df.head())
# Out:
# pandas.core.frame.DataFrame

# %%
# 종목별 ETF OHLCV 조회
# input : 날짜
df = stock.get_etf_ohlcv_by_ticker("20210325")
df

# %%
from pykrx import stock
from dataclasses import dataclass
import time

@dataclass
class Info:
  close: int = None
  volume_buy: int = None
  volume_sell: int = None
  volume_netbuy: int = None
  amount_buy: int = None
  amount_sell: int = None
  amount_netbuy: int = None
  individual_volume_buy: int = None
  individual_volume_sell: int = None
  individual_volume_netbuy: int = None
  individual_amount_buy: int = None
  individual_amount_sell: int = None
  individual_amount_netbuy: int = None
  foreign_volume_buy: int = None
  foreign_volume_sell: int = None
  foreign_volume_netbuy: int = None
  foreign_amount_buy: int = None
  foreign_amount_sell: int = None
  foreign_amount_netbuy: int = None
  institution_volume_buy: int = None
  institution_volume_sell: int = None
  institution_volume_netbuy: int = None
  institution_amount_buy: int = None
  institution_amount_sell: int = None
  institution_amount_netbuy: int = None
  corporation_volume_buy: int = None
  corporation_volume_sell: int = None
  corporation_volume_netbuy: int = None
  corporation_amount_buy: int = None
  corporation_amount_sell: int = None
  corporation_amount_netbuy: int = None

ticker_name, ticker_info = {}, {}
for ticker in stock.get_market_ticker_list()[:5]:
  name = stock.get_market_ticker_name(ticker)
  ticker_name[ticker] = name
  ticker_info[ticker] = {}

start = "20210825"
end = "20210830"

for ticker in ticker_name:
  df_close = stock.get_market_ohlcv_by_date(start, end, ticker)
  # 날짜(index) : 기관합계 / 기타법인 / 개인 / 외국인합계 / 전체
  df_volume_buy = stock.get_market_trading_volume_by_date(start, end, ticker, on="매수")
  df_volume_sell = stock.get_market_trading_volume_by_date(start, end, ticker, on="매도")
  df_volume_netbuy = stock.get_market_trading_volume_by_date(start, end, ticker, on="순매수")
  time.sleep(1)
  df_amount_buy = stock.get_market_trading_value_by_date(start, end, ticker, on="매수")
  df_amount_sell = stock.get_market_trading_value_by_date(start, end, ticker, on="매도")
  df_amount_netbuy = stock.get_market_trading_value_by_date(start, end, ticker, on="순매수")
  
  for idx in df_close.index:
    date = str(idx).split(' ')[0].replace('-', '')
    ticker_info[ticker][date] = Info()
    ticker_info[ticker][date].close = df_close.loc[idx, "종가"]
    ticker_info[ticker][date].institution_volume_buy, ticker_info[ticker][date].corporation_volume_buy, ticker_info[ticker][date].individual_volume_buy, ticker_info[ticker][date].foreign_volume_buy, ticker_info[ticker][date].volume_buy = df_volume_buy.loc[idx] 
    ticker_info[ticker][date].institution_volume_sell, ticker_info[ticker][date].corporation_volume_sell, ticker_info[ticker][date].individual_volume_sell, ticker_info[ticker][date].foreign_volume_sell, ticker_info[ticker][date].volume_sell = df_volume_sell.loc[idx] 
    ticker_info[ticker][date].institution_volume_netbuy, ticker_info[ticker][date].corporation_volume_netbuy, ticker_info[ticker][date].individual_volume_netbuy, ticker_info[ticker][date].foreign_volume_netbuy, ticker_info[ticker][date].volume_netbuy = df_volume_netbuy.loc[idx] 

    ticker_info[ticker][date].institution_amount_buy, ticker_info[ticker][date].corporation_amount_buy, ticker_info[ticker][date].individual_amount_buy, ticker_info[ticker][date].foreign_amount_buy, ticker_info[ticker][date].amount_buy = df_amount_buy.loc[idx] 
    ticker_info[ticker][date].institution_amount_sell, ticker_info[ticker][date].corporation_amount_sell, ticker_info[ticker][date].individual_amount_sell, ticker_info[ticker][date].foreign_amount_sell, ticker_info[ticker][date].amount_sell = df_amount_sell.loc[idx] 
    ticker_info[ticker][date].institution_amount_netbuy, ticker_info[ticker][date].corporation_amount_netbuy, ticker_info[ticker][date].individual_amount_netbuy, ticker_info[ticker][date].foreign_amount_netbuy, ticker_info[ticker][date].amount_netbuy = df_amount_netbuy.loc[idx] 

  # for idx in df.index:
  #   time.sleep(1)
  #   date = str(idx).split(' ')[0].replace('-', '')
  #   ticker_info[ticker][date] = Info()
  #   ticker_info[ticker][date].close = df.loc[idx, "종가"]
  #   ticker_info[ticker][date].institution
  #   df_buy.loc[idx]

  #   df_volume = stock.get_market_trading_volume_by_investor(date, date, ticker)    
  #   individual_volume = df_volume.loc['개인']
  #   foreign_volume = df_volume.loc['외국인']
  #   pension_volume = df_volume.loc['연기금 등']
  #   institutation_volume = df_volume.loc['기관합계'] - pension_volume
  #   volume = df_volume.loc['전체']
  #   ticker_info[ticker][date].pension_volume_sell, ticker_info[ticker][date].pension_volume_buy, ticker_info[ticker][date].pension_volume_netbuy = pension_volume
  #   ticker_info[ticker][date].institutation_volume_sell, ticker_info[ticker][date].institutation_volume_buy, ticker_info[ticker][date].institutation_volume_netbuy = institutation_volume
  #   ticker_info[ticker][date].individual_volume_sell, ticker_info[ticker][date].individual_volume_buy, ticker_info[ticker][date].individual_volume_netbuy = individual_volume
  #   ticker_info[ticker][date].foreign_volume_sell, ticker_info[ticker][date].foreign_volume_buy, ticker_info[ticker][date].foreign_volume_netbuy = foreign_volume
  #   ticker_info[ticker][date].volume_sell, ticker_info[ticker][date].volume_buy, ticker_info[ticker][date].volume_netbuy = volume

  #   df_amount = stock.get_market_trading_value_by_investor(date, date, ticker)   
  #   individual_amount = df_amount.loc['개인']
  #   foreign_amount = df_amount.loc['외국인']
  #   pension_amount = df_amount.loc['연기금 등']
  #   institutation_amount = df_amount.loc['기관합계'] - pension_amount
  #   amount = df_amount.loc['전체']
  #   ticker_info[ticker][date].pension_amount_sell, ticker_info[ticker][date].pension_amount_buy, ticker_info[ticker][date].pension_amount_netbuy = pension_amount
  #   ticker_info[ticker][date].institutation_amount_sell, ticker_info[ticker][date].institutation_amount_buy, ticker_info[ticker][date].institutation_amount_netbuy = institutation_amount
  #   ticker_info[ticker][date].individual_amount_sell, ticker_info[ticker][date].individual_amount_buy, ticker_info[ticker][date].individual_amount_netbuy = individual_amount
  #   ticker_info[ticker][date].foreign_amount_sell, ticker_info[ticker][date].foreign_amount_buy, ticker_info[ticker][date].foreign_amount_netbuy = foreign_amount
  #   ticker_info[ticker][date].amount_sell, ticker_info[ticker][date].amount_buy, ticker_info[ticker][date].amount_netbuy, = amount

ticker_info

# %%
# 일자별 ETF OHLCV 조회
# input : 시작날짜, 종료날짜, 종목
#   - d/m/y
df = stock.get_etf_ohlcv_by_date("20210104", "20210108", "292340")
print(df.head())
# Out:
# pandas.core.frame.DataFrame

# %%
# pykrx to csv
from pykrx import stock
import pandas as pd
import time
import os
from openpyxl import load_workbook

try:
  ticker_name, ticker_info = {}, {}
  # for ticker in stock.get_market_ticker_list()[:10]:
  for ticker in stock.get_market_ticker_list()[:5]:
    name = stock.get_market_ticker_name(ticker)
    ticker_name[ticker] = name
  # for ticker in stock.get_market_ticker_list(market='KOSDAQ'):
    # name = stock.get_market_ticker_name(ticker)
    # ticker_name[ticker] = name

  start = "20210330"
  end = "20210902"

  for ticker in ticker_name:
    try:
      df = stock.get_market_ohlcv_by_date(start, end, ticker)
      # 날짜(index) : 기관합계 / 기타법인 / 개인 / 외국인합계 / 전체
      # df_volume_buy = stock.get_market_trading_volume_by_date(start, end, ticker, on="매수").rename(columns={'기관합계':'기관합계(거래량)-매수', '기타법인':'기타법인(거래량)-매수', '개인':'개인(거래량)-매수', '외국인합계':'외국인합계(거래량)-매수', '전체':'전체(거래량)-매수'})
      # df_volume_sell = stock.get_market_trading_volume_by_date(start, end, ticker, on="매도").rename(columns={'기관합계':'기관합계(거래량)-매도', '기타법인':'기타법인(거래량)-매도', '개인':'개인(거래량)-매도', '외국인합계':'외국인합계(거래량)-매도', '전체':'전체(거래량)-매도'})
      df_volume_netbuy = stock.get_market_trading_volume_by_date(start, end, ticker, on="순매수").rename(columns={'기관합계':'기관합계(거래량)-순매수', '기타법인':'기타법인(거래량)-순매수', '개인':'개인(거래량)-순매수', '외국인합계':'외국인합계(거래량)-순매수', '전체':'전체(거래량)-순매수'})
      time.sleep(1)
      # df_amount_buy = stock.get_market_trading_value_by_date(start, end, ticker, on="매수").rename(columns={'기관합계':'기관합계(거래대금)-매수', '기타법인':'기타법인(거래대금)-매수', '개인':'개인(거래대금)-매수', '외국인합계':'외국인합계(거래대금)-매수', '전체':'전체(거래대금)-매수'})
      # df_amount_sell = stock.get_market_trading_value_by_date(start, end, ticker, on="매도").rename(columns={'기관합계':'기관합계(거래대금)-매도', '기타법인':'기타법인(거래대금)-매도', '개인':'개인(거래대금)-매도', '외국인합계':'외국인합계(거래대금)-매도', '전체':'전체(거래대금)-매도'})
      df_amount_netbuy = stock.get_market_trading_value_by_date(start, end, ticker, on="순매수").rename(columns={'기관합계':'기관합계(거래대금)-순매수', '기타법인':'기타법인(거래대금)-순매수', '개인':'개인(거래대금)-순매수', '외국인합계':'외국인합계(거래대금)-순매수', '전체':'전체(거래대금)-순매수'})
      # df_foreign = stock.get_exhaustion_rates_of_foreign_investment_by_date(start, end, ticker)

      df_total = pd.concat([df, df_volume_netbuy, df_amount_netbuy], axis = 1, join='inner')
      df_total.insert(0, '티커', str(ticker))
      df_total.insert(1, '종목이름', ticker_name[ticker])
      ticker_info[ticker] = df_total

      if not os.path.exists('test.csv'):
        ticker_info[ticker].to_csv('test.csv', sep=',', mode='w', encoding='utf-8-sig')
      else:
        ticker_info[ticker].to_csv('test.csv', sep=',', mode='a', encoding='utf-8-sig', header=False)
    except:
      pass
except Exception as ex:
  print(ex)

# %%
# pykrx to mysql
from sqlalchemy import create_engine
import pymysql
import pandas as pd
from pykrx import stock
import time
from openpyxl import load_workbook
from datetime import datetime, timedelta

try:
  ticker_name = {}
  for ticker in stock.get_market_ticker_list():
    name = stock.get_market_ticker_name(ticker)
    ticker_name[ticker] = name
  for ticker in stock.get_market_ticker_list(market='KOSDAQ'):
    name = stock.get_market_ticker_name(ticker)
    ticker_name[ticker] = name

  start = "20210903"
  end = str(datetime.now().date()).replace('-', '')
  

  for ticker in ticker_name:
    print(ticker)
    try:
      df = stock.get_market_ohlcv_by_date(start, end, ticker).drop(['시가', '고가', '저가'], axis=1).rename(columns={'종가':'close', '거래량':'volume'})
      df.index.names = ['date']
      df_volume_netbuy = stock.get_market_trading_volume_by_date(start, end, ticker, on="순매수").rename(columns={'기관합계':'insVol', '기타법인':'etcVol', '개인':'indVol', '외국인합계':'forVol'}).drop(['전체'], axis=1)
      df_amount_netbuy = stock.get_market_trading_value_by_date(start, end, ticker, on="순매수").rename(columns={'기관합계':'insAmt', '기타법인':'etcAmt', '개인':'indAmt', '외국인합계':'forAmt'}).drop(['전체'], axis=1)
      df_total = pd.concat([df, df_volume_netbuy, df_amount_netbuy], axis = 1, join='inner')
      df_total.insert(0, 'ticker', str(ticker))
      df_total.insert(1, 'name', ticker_name[ticker])

      # db_connection = create_engine('mysql+pymysql://root:test@192.168.56.100:3306/INDEX_DUCK', encoding='utf-8')
      db_connection = create_engine('mysql+pymysql://root:root@192.168.56.100:3306/INDEX_DUCK', encoding='utf-
# Expecting value: line 1 column 1 (char 0)
# 076610
# Expecting value: line 1 column 1 (char 0)
# 059270
# Expecting value: line 1 column 1 (char 0)
# 220180
# Expecting value: line 1 column 1 (char 0)
# 900270
# Expecting value: line 1 column 1 (char 0)
# 084990
# Expecting value: line 1 column 1 (char 0)
# 170030
# Expecting value: line 1 column 1 (char 0)
# 319400
# Expecting value: line 1 column 1 (char 0)
# 048410
# Expecting value: line 1 column 1 (char 0)
# 052260
# Expecting value: line 1 column 1 (char 0)
# 016790
# Expecting value: line 1 column 1 (char 0)
# 041440
# Expecting value: line 1 column 1 (char 0)
# 039010
# Expecting value: line 1 column 1 (char 0)
# 090850
# Expecting value: line 1 column 1 (char 0)
# 092300
# Expecting value: line 1 column 1 (char 0)
# 053660
# Expecting value: line 1 column 1 (char 0)
# 138360
# Expecting value: line 1 column 1 (char 0)
# 011080
# Expecting value: line 1 column 1 (char 0)
# 060560
# Expecting value: line 1 column 1 (char 0)
# 064240
# Expecting value: line 1 column 1 (char 0)
# 039610
# Expecting value: line 1 column 1 (char 0)
# 126640
# Expecting value: line 1 column 1 (char 0)
# 061250
# Expecting value: line 1 column 1 (char 0)
# 097870
# Expecting value: line 1 column 1 (char 0)
# 050090
# Expecting value: line 1 column 1 (char 0)
# 290270
# Expecting value: line 1 column 1 (char 0)
# 353190
# Expecting value: line 1 column 1 (char 0)
# 090710
# Expecting value: line 1 column 1 (char 0)
# 205470
# Expecting value: line 1 column 1 (char 0)
# 115160
# Expecting value: line 1 column 1 (char 0)
# 028080
# Expecting value: line 1 column 1 (char 0)
# 032860
# Expecting value: line 1 column 1 (char 0)
# 200670
# Expecting value: line 1 column 1 (char 0)
# 065510
# Expecting value: line 1 column 1 (char 0)
# 215090
# Expecting value: line 1 column 1 (char 0)
# 243070
# Expecting value: line 1 column 1 (char 0)
# 084110
# Expecting value: line 1 column 1 (char 0)
# 263920
# Expecting value: line 1 column 1 (char 0)
# 145020
# Expecting value: line 1 column 1 (char 0)
# 024060
# Expecting value: line 1 column 1 (char 0)
# 010240
# Expecting value: line 1 column 1 (char 0)
# 189980
# Expecting value: line 1 column 1 (char 0)
# 037440
# Expecting value: line 1 column 1 (char 0)
# 238490
# Expecting value: line 1 column 1 (char 0)

# %%
# 누적 순매수 계산
import pandas as pd
import pymysql
from datetime import datetime, timedelta

periods = [['last_1m', 1], ['last_3m', 3], ['last_6m', 6], ['last_12m', 12]]

### Drop table
try:
  db = pymysql.connect(host='192.168.56.100', port=3306, user='root', passwd='root', db='INDEX_DUCK', charset='utf8', cursorclass=pymysql.cursors.DictCursor)
  cursor = db.cursor()
  dropTableSql = "DROP TABLE last_1m, last_3m, last_6m, last_12m"
  cursor.execute(dropTableSql)
  for period in periods:
    createTableSql = """
      CREATE TABLE %s  (
        date        date,
        ticker      varchar(10),
        name        varchar(255),
        close       bigint,
        volume      bigint,
        insVolCum   bigint,
        etcVolCum   bigint,
        indVolCum   bigint,
        forVolCum   bigint,
        insAmtCum   bigint,
        etcAmtCum   bigint,
        indAmtCum   bigint,
        forAmtCum   bigint,
        primary key (ticker, date)
      ) engine = InnoDB;
    """ % (period)
    cursor.execute(createTableSql)
  db.commit()
  db.close()
except Exception as e:
  print(e)
  pass

db = pymysql.connect(host='192.168.56.100', port=3306, user='root', passwd='root', db='INDEX_DUCK', charset='utf8')
cursor = db.cursor()
try:
  getTickersSql = "SELECT DISTINCT ticker FROM stocks"
  cursor.execute(getTickersSql)
  tickers = list(cursor.fetchall())


  for period in periods:
    date = str((datetime.now() - timedelta(weeks=period[1]*4)).date())
    for ticker in tickers:
      print(ticker)
      getTickerInfoSql = "SELECT * FROM stocks WHERE ticker = '" + ticker[0] + "' AND date > '" + date + "'"
      cursor.execute(getTickerInfoSql)
      tickerInfos = list(map(list, cursor.fetchall()))
      if len(tickerInfos) < 1:
        continue

      tickerInfos[0] += [tickerInfos[0][i] for i in range(5, 13)]
      for idx in range(1, len(tickerInfos)):
        befInfo = tickerInfos[idx - 1]
        info = tickerInfos[idx]
        tmpCum = [a + b for a, b in zip(befInfo[13:], info[5:])]
        tickerInfos[idx] = tickerInfos[idx][:5] + tmpCum
      try:
        updateInfoSql = "REPLACE INTO " + period[0] + "(date, ticker, name, close, volume, insVolCum, etcVolCum, indVolCum, forVolCum, insAmtCum, etcAmtCum, indAmtCum, forAmtCum) VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        cursor.executemany(updateInfoSql, tickerInfos)
        db.commit()
      except Exception as ex1:
        print('ex1', ex1)
        pass
except Exception as ex2:
  print('ex2', ex2)
  pass

db.close()
# Out:
# (1051, "Unknown table 'INDEX_DUCK.last_1m,INDEX_DUCK.last_3m,INDEX_DUCK.last_6m,INDEX_DUCK.last_12m'")
# ('000020',)
# ex1 not all arguments converted during string formatting
# ('000040',)
# ex1 not all arguments converted during string formatting
# ('000050',)
# ex1 not all arguments converted during string formatting
# ('000060',)
# ex1 not all arguments converted during string formatting
# ('000070',)
# ex1 not all arguments converted during string formatting
# ('000075',)
# ex1 not all arguments converted during string formatting
# ('000080',)
# ex1 not all arguments converted during string formatting
# ('000087',)
# ex1 not all arguments converted during string formatting
# ('000100',)
# ex1 not all arguments converted during string formatting
# ('000105',)
# ex1 not all arguments converted during string formatting
# ('000120',)
# ex1 not all arguments converted during string formatting
# ('000140',)
# ex1 not all arguments converted during string formatting
# ('000145',)
# ex1 not all arguments converted during string formatting
# ('000150',)
# ex1 not all arguments converted during string formatting
# ('000155',)
# ex1 not all arguments converted during string formatting
# ('000157',)
# ex1 not all arguments converted during string formatting
# ('000180',)
# ex1 not all arguments converted during string formatting
# ('000210',)
# ex1 not all arguments converted during string formatting
# ('000215',)
# ex1 not all arguments converted during string formatting
# ('000220',)
# ex1 not all arguments converted during string formatting
# ('000225',)
# ex1 not all arguments converted during string formatting
# ('000227',)
# ex1 not all arguments converted during string formatting
# ('000230',)
# ex1 not all arguments converted during string formatting
# ('000240',)
# ex1 not all arguments converted during string formatting
# ('000250',)
# ex1 not all arguments converted during string formatting
# ('000270',)
# ex1 not all arguments converted during string formatting
# ('000300',)
# ex1 not all arguments converted during string formatting
# ('000320',)
# ex1 not all arguments converted during string formatting
# ('000325',)
# ex1 not all arguments converted during string formatting
# ('000370',)
# ex1 not all arguments converted during string formatting
# ('000390',)
# ex1 not all arguments converted during string formatting
# ('000400',)
# ex1 not all arguments converted during string formatting
# ('000430',)
# ex1 not all arguments converted during string formatting
# ('000440',)
# ex1 not all arguments converted during string formatting
# ('000480',)
# ex1 not all arguments converted during string formatting
# ('000490',)
# ex1 not all arguments converted during string formatting
# ('000500',)
# ex1 not all arguments converted during string formatting
# ('000520',)
# ex1 not all arguments converted during string formatting
# ('000540',)
# ex1 not all arguments converted during string formatting
# ('000545',)
# ex1 not all arguments converted during string formatting
# ('000547',)
# ex1 not all arguments converted during string formatting
# ('000590',)
# ex1 not all arguments converted during string formatting
# ('000640',)
# ex1 not all arguments converted during string formatting
# ('000650',)
# ex1 not all arguments converted during string formatting
# ('000660',)
# ex1 not all arguments converted during string formatting
# ('000670',)
# ex1 not all arguments converted during string formatting
# ('000680',)
# ex1 not all arguments converted during string formatting
# ('000700',)
# ex1 not all arguments converted during string formatting
# ('000720',)
# ex1 not all arguments converted during string formatting
# ('000725',)
# ex1 not all arguments converted during string formatting
# ('000760',)
# ex1 not all arguments converted during string formatting
# ('000810',)
# ex1 not all arguments converted during string formatting
# ('000815',)
# ex1 not all arguments converted during string formatting
# ('000850',)
# ex1 not all arguments converted during string formatting
# ('000860',)
# ex1 not all arguments converted during string formatting
# ('000880',)
# ex1 not all arguments converted during string formatting
# ('000885',)
# ex1 not all arguments converted during string formatting
# ('00088K',)
# ex1 not all arguments converted during string formatting
# ('000890',)
# ex1 not all arguments converted during string formatting
# ('000910',)
# ex1 not all arguments converted during string formatting
# ('000950',)
# ex1 not all arguments converted during string formatting
# ('000970',)
# ex1 not all arguments converted during string formatting
# ('000990',)
# ex1 not all arguments converted during string formatting
# ('000995',)
# ex1 not all arguments converted during string formatting
# ('001000',)
# ex1 not all arguments converted during string formatting
# ('001020',)
# ex1 not all arguments converted during string formatting
# ('001040',)
# ex1 not all arguments converted during string formatting
# ('001045',)
# ex1 not all arguments converted during string formatting
# ('00104K',)
# ex1 not all arguments converted during string formatting
# ('001060',)
# ex1 not all arguments converted during string formatting
# ('001065',)
# ex1 not all arguments converted during string formatting
# ('001067',)
# ex1 not all arguments converted during string formatting
# ('001070',)
# ex1 not all arguments converted during string formatting
# ('001080',)
# ex1 not all arguments converted during string formatting
# ('001120',)
# ex1 not all arguments converted during string formatting
# ('001130',)
# ex1 not all arguments converted during string formatting
# ('001140',)
# ex1 not all arguments converted during string formatting
# ('001200',)
# ex1 not all arguments converted during string formatting
# ('001210',)
# ex1 not all arguments converted during string formatting
# ('001230',)
# ex1 not all arguments converted during string formatting
# ('001250',)
# ex1 not all arguments converted during string formatting
# ('001260',)
# ex1 not all arguments converted during string formatting
# ('001270',)
# ex1 not all arguments converted during string formatting
# ('001275',)
# ex1 not all arguments converted during string formatting
# ('001290',)
# ex1 not all arguments converted during string formatting
# ('001340',)
# ex1 not all arguments converted during string formatting
# ('001360',)
# ex1 not all arguments converted during string formatting
# ('001380',)
# ex1 not all arguments converted during string formatting
# ('001390',)
# ex1 not all arguments converted during string formatting
# ('001420',)
# ex1 not all arguments converted during string formatting
# ('001430',)
# ex1 not all arguments converted during string formatting
# ('001440',)
# ex1 not all arguments converted during string formatting
# ('001450',)
# ex1 not all arguments converted during string formatting
# ('001460',)
# ex1 not all arguments converted during string formatting
# ('001465',)
# ex1 not all arguments converted during string formatting
# ('001470',)
# ex1 not all arguments converted during string formatting
# ('001500',)
# ex1 not all arguments converted during string formatting
# ('001510',)
# ex1 not all arguments converted during string formatting
# ('001515',)
# ex1 not all arguments converted during string formatting
# ('001520',)
# ex1 not all arguments converted during string formatting
# ('001525',)
# ex1 not all arguments converted during string formatting
# ('001527',)
# ex1 not all arguments converted during string formatting
# ('001529',)
# ex1 not all arguments converted during string formatting
# ('001530',)
# ex1 not all arguments converted during string formatting
# ('001540',)
# ex1 not all arguments converted during string formatting
# ('001550',)
# ex1 not all arguments converted during string formatting
# ('001560',)
# ex1 not all arguments converted during string formatting
# ('001570',)
# ex1 not all arguments converted during string formatting
# ('001620',)
# ex1 not all arguments converted during string formatting
# ('001630',)
# ex1 not all arguments converted during string formatting
# ('001680',)
# ex1 not all arguments converted during string formatting
# ('001685',)
# ex1 not all arguments converted during string formatting
# ('001720',)
# ex1 not all arguments converted during string formatting
# ('001725',)
# ex1 not all arguments converted during string formatting
# ('001740',)
# ex1 not all arguments converted during string formatting
# ('001745',)
# ex1 not all arguments converted during string formatting
# ('001750',)
# ex1 not all arguments converted during string formatting
# ('001755',)
# ex1 not all arguments converted during string formatting
# ('001770',)
# ex1 not all arguments converted during string formatting
# ('001780',)
# ex1 not all arguments converted during string formatting
# ('001790',)
# ex1 not all arguments converted during string formatting
# ('001795',)
# ex1 not all arguments converted during string formatting
# ('001800',)
# ex1 not all arguments converted during string formatting
# ('001810',)
# ex1 not all arguments converted during string formatting
# ('001820',)
# ex1 not all arguments converted during string formatting
# ('001840',)
# ex1 not all arguments converted during string formatting
# ('001880',)
# ex1 not all arguments converted during string formatting
# ('001940',)
# ex1 not all arguments converted during string formatting
# ('002020',)
# ex1 not all arguments converted during string formatting
# ('002025',)
# ex1 not all arguments converted during string formatting
# ('002030',)
# ex1 not all arguments converted during string formatting
# ('002070',)
# ex1 not all arguments converted during string formatting
# ('002100',)
# ex1 not all arguments converted during string formatting
# ('002140',)
# ex1 not all arguments converted during string formatting
# ('002150',)
# ex1 not all arguments converted during string formatting
# ('002170',)
# ex1 not all arguments converted during string formatting
# ('002200',)
# ex1 not all arguments converted during string formatting
# ('002210',)
# ex1 not all arguments converted during string formatting
# ('002220',)
# ex1 not all arguments converted during string formatting
# ('002230',)
# ex1 not all arguments converted during string formatting
# ('002240',)
# ex1 not all arguments converted during string formatting
# ('002270',)
# ex1 not all arguments converted during string formatting
# ('002290',)
# ex1 not all arguments converted during string formatting
# ('002310',)
# ex1 not all arguments converted during string formatting
# ('002320',)
# ex1 not all arguments converted during string formatting
# ('002350',)
# ex1 not all arguments converted during string formatting
# ('002355',)
# ex1 not all arguments converted during string formatting
# ('002360',)
# ex1 not all arguments converted during string formatting
# ('002380',)
# ex1 not all arguments converted during string formatting
# ('002390',)
# ex1 not all arguments converted during string formatting
# ('002410',)
# ex1 not all arguments converted during string formatting
# ('002450',)
# ex1 not all arguments converted during string formatting
# ('002460',)
# ex1 not all arguments converted during string formatting
# ('002600',)
# ex1 not all arguments converted during string formatting
# ('002620',)
# ex1 not all arguments converted during string formatting
# ('002630',)
# ex1 not all arguments converted during string formatting
# ('002680',)
# ex1 not all arguments converted during string formatting
# ('002690',)
# ex1 not all arguments converted during string formatting
# ('002700',)
# ex1 not all arguments converted during string formatting
# ('002710',)
# ex1 not all arguments converted during string formatting
# ('002720',)
# ex1 not all arguments converted during string formatting
# ('002760',)
# ex1 not all arguments converted during string formatting
# ('002780',)
# ex1 not all arguments converted during string formatting
# ('002785',)
# ex1 not all arguments converted during string formatting
# ('002787',)
# ex1 not all arguments converted during string formatting
# ('002790',)
# ex1 not all arguments converted during string formatting
# ('002795',)
# ex1 not all arguments converted during string formatting
# ('00279K',)
# ex1 not all arguments converted during string formatting
# ('002800',)
# ex1 not all arguments converted during string formatting
# ('002810',)
# ex1 not all arguments converted during string formatting
# ('002820',)
# ex1 not all arguments converted during string formatting
# ('002840',)
# ex1 not all arguments converted during string formatting
# ('002870',)
# ex1 not all arguments converted during string formatting
# ('002880',)
# ex1 not all arguments converted during string formatting
# ('002900',)
# ex1 not all arguments converted during string formatting
# ('002920',)
# ex1 not all arguments converted during string formatting
# ('002960',)
# ex1 not all arguments converted during string formatting
# ('002990',)
# ex1 not all arguments converted during string formatting
# ('002995',)
# ex1 not all arguments converted during string formatting
# ('003000',)
# ex1 not all arguments converted during string formatting
# ('003010',)
# ex1 not all arguments converted during string formatting
# ('003030',)
# ex1 not all arguments converted during string formatting
# ('003060',)
# ex1 not all arguments converted during string formatting
# ('003070',)
# ex1 not all arguments converted during string formatting
# ('003075',)
# ex1 not all arguments converted during string formatting
# ('003080',)
# ex1 not all arguments converted during string formatting
# ('003090',)
# ex1 not all arguments converted during string formatting
# ('003100',)
# ex1 not all arguments converted during string formatting
# ('003120',)
# ex1 not all arguments converted during string formatting
# ('003160',)
# ex1 not all arguments converted during string formatting
# ('003200',)
# ex1 not all arguments converted during string formatting
# ('003220',)
# ex1 not all arguments converted during string formatting
# ('003230',)
# ex1 not all arguments converted during string formatting
# ('003240',)
# ex1 not all arguments converted during string formatting
# ('003280',)
# ex1 not all arguments converted during string formatting
# ('003300',)
# ex1 not all arguments converted during string formatting
# ('003310',)
# ex1 not all arguments converted during string formatting
# ('003350',)
# ex1 not all arguments converted during string formatting
# ('003380',)
# ex1 not all arguments converted during string formatting
# ('003410',)
# ex1 not all arguments converted during string formatting
# ('003460',)
# ex1 not all arguments converted during string formatting
# ('003465',)
# ex1 not all arguments converted during string formatting
# ('003470',)
# ex1 not all arguments converted during string formatting
# ('003475',)
# ex1 not all arguments converted during string formatting
# ('003480',)
# ex1 not all arguments converted during string formatting
# ('003490',)
# ex1 not all arguments converted during string formatting
# ('003495',)
# ex1 not all arguments converted during string formatting
# ('003520',)
# ex1 not all arguments converted during string formatting
# ('003530',)
# ex1 not all arguments converted during string formatting
# ('003535',)
# ex1 not all arguments converted during string formatting
# ('003540',)
# ex1 not all arguments converted during string formatting
# ('003545',)
# ex1 not all arguments converted during string formatting
# ('003547',)
# ex1 not all arguments converted during string formatting
# ('003550',)
# ex1 not all arguments converted during string formatting
# ('003555',)
# ex1 not all arguments converted during string formatting
# ('003560',)
# ex1 not all arguments converted during string formatting
# ('003570',)
# ex1 not all arguments converted during string formatting
# ('003580',)
# ex1 not all arguments converted during string formatting
# ('003610',)
# ex1 not all arguments converted during string formatting
# ('003650',)
# ex1 not all arguments converted during string formatting
# ('003670',)
# ex1 not all arguments converted during string formatting
# ('003680',)
# ex1 not all arguments converted during string formatting
# ('003690',)
# ex1 not all arguments converted during string formatting
# ('003720',)
# ex1 not all arguments converted during string formatting
# ('003780',)
# ex1 not all arguments converted during string formatting
# ('003800',)
# ex1 not all arguments converted during string formatting
# ('003830',)
# ex1 not all arguments converted during string formatting
# ('003850',)
# ex1 not all arguments converted during string formatting
# ('003920',)
# ex1 not all arguments converted during string formatting
# ('003925',)
# ex1 not all arguments converted during string formatting
# ('003960',)
# ex1 not all arguments converted during string formatting
# ('004000',)
# ex1 not all arguments converted during string formatting
# ('004020',)
# ex1 not all arguments converted during string formatting
# ('004060',)
# ex1 not all arguments converted during string formatting
# ('004080',)
# ex1 not all arguments converted during string formatting
# ('004090',)
# ex1 not all arguments converted during string formatting
# ('004100',)
# ex1 not all arguments converted during string formatting
# ('004105',)
# ex1 not all arguments converted during string formatting
# ('004140',)
# ex1 not all arguments converted during string formatting
# ('004150',)
# ex1 not all arguments converted during string formatting
# ('004170',)
# ex1 not all arguments converted during string formatting
# ('004250',)
# ex1 not all arguments converted during string formatting
# ('004255',)
# ex1 not all arguments converted during string formatting
# ('004270',)
# ex1 not all arguments converted during string formatting
# ('004310',)
# ex1 not all arguments converted during string formatting
# ('004360',)
# ex1 not all arguments converted during string formatting
# ('004365',)
# ex1 not all arguments converted during string formatting
# ('004370',)
# ex1 not all arguments converted during string formatting
# ('004380',)
# ex1 not all arguments converted during string formatting
# ('004410',)
# ex1 not all arguments converted during string formatting
# ('004415',)
# ex1 not all arguments converted during string formatting
# ('004430',)
# ex1 not all arguments converted during string formatting
# ('004440',)
# ex1 not all arguments converted during string formatting
# ('004450',)
# ex1 not all arguments converted during string formatting
# ('004490',)
# ex1 not all arguments converted during string formatting
# ('004540',)
# ex1 not all arguments converted during string formatting
# ('004545',)
# ex1 not all arguments converted during string formatting
# ('004560',)
# ex1 not all arguments converted during string formatting
# ('004565',)
# ex1 not all arguments converted during string formatting
# ('004590',)
# ex1 not all arguments converted during string formatting
# ('004650',)
# ex1 not all arguments converted during string formatting
# ('004690',)
# ex1 not all arguments converted during string formatting
# ('004700',)
# ex1 not all arguments converted during string formatting
# ('004710',)
# ex1 not all arguments converted during string formatting
# ('004720',)
# ex1 not all arguments converted during string formatting
# ('004770',)
# ex1 not all arguments converted during string formatting
# ('004780',)
# ex1 not all arguments converted during string formatting
# ('004800',)
# ex1 not all arguments converted during string formatting
# ('004830',)
# ex1 not all arguments converted during string formatting
# ('004835',)
# ex1 not all arguments converted during string formatting
# ('004840',)
# ex1 not all arguments converted during string formatting
# ('004870',)
# ex1 not all arguments converted during string formatting
# ('004890',)
# ex1 not all arguments converted during string formatting
# ('004910',)
# ex1 not all arguments converted during string formatting
# ('004920',)
# ex1 not all arguments converted during string formatting
# ('004960',)
# ex1 not all arguments converted during string formatting
# ('004970',)
# ex1 not all arguments converted during string formatting
# ('004980',)
# ex1 not all arguments converted during string formatting
# ('004985',)
# ex1 not all arguments converted during string formatting
# ('004990',)
# ex1 not all arguments converted during string formatting
# ('00499K',)
# ex1 not all arguments converted during string formatting
# ('005010',)
# ex1 not all arguments converted during string formatting
# ('005030',)
# ex1 not all arguments converted during string formatting
# ('005070',)
# ex1 not all arguments converted during string formatting
# ('005090',)
# ex1 not all arguments converted during string formatting
# ('005110',)
# ex1 not all arguments converted during string formatting
# ('005160',)
# ex1 not all arguments converted during string formatting
# ('005180',)
# ex1 not all arguments converted during string formatting
# ('005250',)
# ex1 not all arguments converted during string formatting
# ('005257',)
# ex1 not all arguments converted during string formatting
# ('005290',)
# ex1 not all arguments converted during string formatting
# ('005300',)
# ex1 not all arguments converted during string formatting
# ('005305',)
# ex1 not all arguments converted during string formatting
# ('005320',)
# ex1 not all arguments converted during string formatting
# ('005360',)
# ex1 not all arguments converted during string formatting
# ('005380',)
# ex1 not all arguments converted during string formatting
# ('005385',)
# ex1 not all arguments converted during string formatting
# ('005387',)
# ex1 not all arguments converted during string formatting
# ('005389',)
# ex1 not all arguments converted during string formatting
# ('005390',)
# ex1 not all arguments converted during string formatting
# ('005420',)
# ex1 not all arguments converted during string formatting
# ('005430',)
# ex1 not all arguments converted during string formatting
# ('005440',)
# ex1 not all arguments converted during string formatting
# ('005490',)
# ex1 not all arguments converted during string formatting
# ('005500',)
# ex1 not all arguments converted during string formatting
# ('005610',)
# ex1 not all arguments converted during string formatting
# ('005670',)
# ex1 not all arguments converted during string formatting
# ('005680',)
# ex1 not all arguments converted during string formatting
# ('005690',)
# ex1 not all arguments converted during string formatting
# ('005710',)
# ex1 not all arguments converted during string formatting
# ('005720',)
# ex1 not all arguments converted during string formatting
# ('005725',)
# ex1 not all arguments converted during string formatting
# ('005740',)
# ex1 not all arguments converted during string formatting
# ('005745',)
# ex1 not all arguments converted during string formatting
# ('005750',)
# ex1 not all arguments converted during string formatting
# ('005800',)
# ex1 not all arguments converted during string formatting
# ('005810',)
# ex1 not all arguments converted during string formatting
# ('005820',)
# ex1 not all arguments converted during string formatting
# ('005830',)
# ex1 not all arguments converted during string formatting
# ('005850',)
# ex1 not all arguments converted during string formatting
# ('005860',)
# ex1 not all arguments converted during string formatting
# ('005870',)
# ex1 not all arguments converted during string formatting
# ('005880',)
# ex1 not all arguments converted during string formatting
# ('005930',)
# ex1 not all arguments converted during string formatting
# ('005935',)
# ex1 not all arguments converted during string formatting
# ('005940',)
# ex1 not all arguments converted during string formatting
# ('005945',)
# ex1 not all arguments converted during string formatting
# ('005950',)
# ex1 not all arguments converted during string formatting
# ('005960',)
# ex1 not all arguments converted during string formatting
# ('005965',)
# ex1 not all arguments converted during string formatting
# ('005990',)
# ex1 not all arguments converted during string formatting
# ('006040',)
# ex1 not all arguments converted during string formatting
# ('006050',)
# ex1 not all arguments converted during string formatting
# ('006060',)
# ex1 not all arguments converted during string formatting
# ('006090',)
# ex1 not all arguments converted during string formatting
# ('006110',)
# ex1 not all arguments converted during string formatting
# ('006120',)
# ex1 not all arguments converted during string formatting
# ('006125',)
# ex1 not all arguments converted during string formatting
# ('006140',)
# ex1 not all arguments converted during string formatting
# ('006200',)
# ex1 not all arguments converted during string formatting
# ('006220',)
# ex1 not all arguments converted during string formatting
# ('006260',)
# ex1 not all arguments converted during string formatting
# ('006280',)
# ex1 not all arguments converted during string formatting
# ('006340',)
# ex1 not all arguments converted during string formatting
# ('006345',)
# ex1 not all arguments converted during string formatting
# ('006360',)
# ex1 not all arguments converted during string formatting
# ('006370',)
# ex1 not all arguments converted during string formatting
# ('006380',)
# ex1 not all arguments converted during string formatting
# ('006390',)
# ex1 not all arguments converted during string formatting
# ('006400',)
# ex1 not all arguments converted during string formatting
# ('006405',)
# ex1 not all arguments converted during string formatting
# ('006490',)
# ex1 not all arguments converted during string formatting
# ('006570',)
# ex1 not all arguments converted during string formatting
# ('006580',)
# ('006620',)
# ex1 not all arguments converted during string formatting
# ('006650',)
# ex1 not all arguments converted during string formatting
# ('006660',)
# ex1 not all arguments converted during string formatting
# ('006730',)
# ex1 not all arguments converted during string formatting
# ('006740',)
# ex1 not all arguments converted during string formatting
# ('006800',)
# ex1 not all arguments converted during string formatting
# ('006805',)
# ex1 not all arguments converted during string formatting
# ('00680K',)
# ex1 not all arguments converted during string formatting
# ('006840',)
# ex1 not all arguments converted during string formatting
# ('006880',)
# ex1 not all arguments converted during string formatting
# ('006890',)
# ex1 not all arguments converted during string formatting
# ('006910',)
# ex1 not all arguments converted during string formatting
# ('006920',)
# ex1 not all arguments converted during string formatting
# ('006980',)
# ex1 not all arguments converted during string formatting
# ('007070',)
# ex1 not all arguments converted during string formatting
# ('007110',)
# ex1 not all arguments converted during string formatting
# ('007120',)
# ex1 not all arguments converted during string formatting
# ('007160',)
# ex1 not all arguments converted during string formatting
# ('007210',)
# ex1 not all arguments converted during string formatting
# ('007280',)
# ex1 not all arguments converted during string formatting
# ('007310',)
# ex1 not all arguments converted during string formatting
# ('007330',)
# ex1 not all arguments converted during string formatting
# ('007340',)
# ex1 not all arguments converted during string formatting
# ('007370',)
# ex1 not all arguments converted during string formatting
# ('007390',)
# ex1 not all arguments converted during string formatting
# ('007460',)
# ex1 not all arguments converted during string formatting
# ('007530',)
# ex1 not all arguments converted during string formatting
# ('007540',)
# ex1 not all arguments converted during string formatting
# ('007570',)
# ex1 not all arguments converted during string formatting
# ('007575',)
# ex1 not all arguments converted during string formatting
# ('007590',)
# ex1 not all arguments converted during string formatting
# ('007610',)
# ex1 not all arguments converted during string formatting
# ('007660',)
# ex1 not all arguments converted during string formatting
# ('007680',)
# ex1 not all arguments converted during string formatting
# ('007690',)
# ex1 not all arguments converted during string formatting
# ('007700',)
# ex1 not all arguments converted during string formatting
# ('007720',)
# ex1 not all arguments converted during string formatting
# ('007770',)
# ex1 not all arguments converted during string formatting
# ('007810',)
# ex1 not all arguments converted during string formatting
# ('007815',)
# ex1 not all arguments converted during string formatting
# ('00781K',)
# ex1 not all arguments converted during string formatting
# ('007820',)
# ex1 not all arguments converted during string formatting
# ('007860',)
# ex1 not all arguments converted during string formatting
# ('007980',)
# ex1 not all arguments converted during string formatting
# ('008040',)
# ex1 not all arguments converted during string formatting
# ('008060',)
# ex1 not all arguments converted during string formatting
# ('00806K',)
# ex1 not all arguments converted during string formatting
# ('008110',)
# ex1 not all arguments converted during string formatting
# ('008250',)
# ex1 not all arguments converted during string formatting
# ('008260',)
# ex1 not all arguments converted during string formatting
# ('008290',)
# ex1 not all arguments converted during string formatting
# ('008350',)
# ex1 not all arguments converted during string formatting
# ('008355',)
# ex1 not all arguments converted during string formatting
# ('008370',)
# ex1 not all arguments converted during string formatting
# ('008420',)
# ex1 not all arguments converted during string formatting
# ('008470',)
# ex1 not all arguments converted during string formatting
# ('008490',)
# ex1 not all arguments converted during string formatting
# ('008500',)
# ex1 not all arguments converted during string formatting
# ('008560',)
# ex1 not all arguments converted during string formatting
# ('008600',)
# ex1 not all arguments converted during string formatting
# ('008700',)
# ex1 not all arguments converted during string formatting
# ('008730',)
# ex1 not all arguments converted during string formatting
# ('008770',)
# ex1 not all arguments converted during string formatting
# ('008775',)
# ex1 not all arguments converted during string formatting
# ('008830',)
# ex1 not all arguments converted during string formatting
# ('008870',)
# ex1 not all arguments converted during string formatting
# ('008930',)
# ex1 not all arguments converted during string formatting
# ('008970',)
# ex1 not all arguments converted during string formatting
# ('009070',)
# ex1 not all arguments converted during string formatting
# ('009140',)
# ex1 not all arguments converted during string formatting
# ('009150',)
# ex1 not all arguments converted during string formatting
# ('009155',)
# ex1 not all arguments converted during string formatting
# ('009160',)
# ex1 not all arguments converted during string formatting
# ('009180',)
# ex1 not all arguments converted during string formatting
# ('009190',)
# ex1 not all arguments converted during string formatting
# ('009200',)
# ex1 not all arguments converted during string formatting
# ('009240',)
# ex1 not all arguments converted during string formatting
# ('009270',)
# ex1 not all arguments converted during string formatting
# ('009275',)
# ex1 not all arguments converted during string formatting
# ('009290',)
# ex1 not all arguments converted during string formatting
# ('009300',)
# ex1 not all arguments converted during string formatting
# ('009310',)
# ex1 not all arguments converted during string formatting
# ('009320',)
# ex1 not all arguments converted during string formatting
# ('009410',)
# ex1 not all arguments converted during string formatting
# ('009415',)
# ex1 not all arguments converted during string formatting
# ('009420',)
# ex1 not all arguments converted during string formatting
# ('009440',)
# ex1 not all arguments converted during string formatting
# ('009450',)
# ex1 not all arguments converted during string formatting
# ('009460',)
# ex1 not all arguments converted during string formatting
# ('009470',)
# ex1 not all arguments converted during string formatting
# ('009520',)
# ex1 not all arguments converted during string formatting
# ('009540',)
# ex1 not all arguments converted during string formatting
# ('009580',)
# ex1 not all arguments converted during string formatting
# ('009620',)
# ex1 not all arguments converted during string formatting
# ('009680',)
# ex1 not all arguments converted during string formatting
# ('009770',)
# ex1 not all arguments converted during string formatting
# ('009780',)
# ex1 not all arguments converted during string formatting
# ('009810',)
# ex1 not all arguments converted during string formatting
# ('009830',)
# ex1 not all arguments converted during string formatting
# ('009835',)
# ex1 not all arguments converted during string formatting
# ('009900',)
# ex1 not all arguments converted during string formatting
# ('009970',)
# ex1 not all arguments converted during string formatting
# ('010040',)
# ex1 not all arguments converted during string formatting
# ('010050',)
# ex1 not all arguments converted during string formatting
# ('010060',)
# ex1 not all arguments converted during string formatting
# ('010100',)
# ex1 not all arguments converted during string formatting
# ('010120',)
# ex1 not all arguments converted during string formatting
# ('010130',)
# ex1 not all arguments converted during string formatting
# ('010140',)
# ex1 not all arguments converted during string formatting
# ('010145',)
# ex1 not all arguments converted during string formatting
# ('010170',)
# ex1 not all arguments converted during string formatting
# ('010240',)
# ex1 not all arguments converted during string formatting
# ('010280',)
# ex1 not all arguments converted during string formatting
# ('010400',)
# ex1 not all arguments converted during string formatting
# ('010420',)
# ex1 not all arguments converted during string formatting
# ('010470',)
# ex1 not all arguments converted during string formatting
# ('010600',)
# ex1 not all arguments converted during string formatting
# ('010620',)
# ex1 not all arguments converted during string formatting
# ('010640',)
# ex1 not all arguments converted during string formatting
# ('010660',)
# ex1 not all arguments converted during string formatting
# ('010690',)
# ex1 not all arguments converted during string formatting
# ('010770',)
# ex1 not all arguments converted during string formatting
# ('010780',)
# ex1 not all arguments converted during string formatting
# ('010820',)
# ex1 not all arguments converted during string formatting
# ('010950',)
# ex1 not all arguments converted during string formatting
# ('010955',)
# ex1 not all arguments converted during string formatting
# ('010960',)
# ex1 not all arguments converted during string formatting
# ('011000',)
# ex1 not all arguments converted during string formatting
# ('011040',)
# ex1 not all arguments converted during string formatting
# ('011070',)
# ex1 not all arguments converted during string formatting
# ('011080',)
# ex1 not all arguments converted during string formatting
# ('011090',)
# ex1 not all arguments converted during string formatting
# ('011150',)
# ex1 not all arguments converted during string formatting
# ('011155',)
# ex1 not all arguments converted during string formatting
# ('011170',)
# ex1 not all arguments converted during string formatting
# ('011200',)
# ex1 not all arguments converted during string formatting
# ('011210',)
# ex1 not all arguments converted during string formatting
# ('011230',)
# ex1 not all arguments converted during string formatting
# ('011280',)
# ex1 not all arguments converted during string formatting
# ('011300',)
# ('011320',)
# ex1 not all arguments converted during string formatting
# ('011330',)
# ex1 not all arguments converted during string formatting
# ('011370',)
# ex1 not all arguments converted during string formatting
# ('011390',)
# ex1 not all arguments converted during string formatting
# ('011420',)
# ex1 not all arguments converted during string formatting
# ('011500',)
# ex1 not all arguments converted during string formatting
# ('011560',)
# ex1 not all arguments converted during string formatting
# ('011700',)
# ex1 not all arguments converted during string formatting
# ('011760',)
# ex1 not all arguments converted during string formatting
# ('011780',)
# ex1 not all arguments converted during string formatting
# ('011785',)
# ex1 not all arguments converted during string formatting
# ('011790',)
# ex1 not all arguments converted during string formatting
# ('011810',)
# ex1 not all arguments converted during string formatting
# ('011930',)
# ex1 not all arguments converted during string formatting
# ('012030',)
# ex1 not all arguments converted during string formatting
# ('012160',)
# ex1 not all arguments converted during string formatting
# ('012170',)
# ex1 not all arguments converted during string formatting
# ('012200',)
# ex1 not all arguments converted during string formatting
# ('012205',)
# ex1 not all arguments converted during string formatting
# ('012280',)
# ex1 not all arguments converted during string formatting
# ('012320',)
# ex1 not all arguments converted during string formatting
# ('012330',)
# ex1 not all arguments converted during string formatting
# ('012340',)
# ex1 not all arguments converted during string formatting
# ('012450',)
# ex1 not all arguments converted during string formatting
# ('012510',)
# ex1 not all arguments converted during string formatting
# ('012600',)
# ('012610',)
# ex1 not all arguments converted during string formatting
# ('012620',)
# ex1 not all arguments converted during string formatting
# ('012630',)
# ex1 not all arguments converted during string formatting
# ('012690',)
# ex1 not all arguments converted during string formatting
# ('012700',)
# ex1 not all arguments converted during string formatting
# ('012750',)
# ex1 not all arguments converted during string formatting
# ('012790',)
# ex1 not all arguments converted during string formatting
# ('012800',)
# ex1 not all arguments converted during string formatting
# ('012860',)
# ex1 not all arguments converted during string formatting
# ('013000',)
# ('013030',)
# ex1 not all arguments converted during string formatting
# ('013120',)
# ex1 not all arguments converted during string formatting
# ('013310',)
# ex1 not all arguments converted during string formatting
# ('013360',)
# ex1 not all arguments converted during string formatting
# ('013520',)
# ex1 not all arguments converted during string formatting
# ('013570',)
# ex1 not all arguments converted during string formatting
# ('013580',)
# ex1 not all arguments converted during string formatting
# ('013700',)
# ex1 not all arguments converted during string formatting
# ('013720',)
# ex1 not all arguments converted during string formatting
# ('013810',)
# ex1 not all arguments converted during string formatting
# ('013870',)
# ex1 not all arguments converted during string formatting
# ('013890',)
# ex1 not all arguments converted during string formatting
# ('013990',)
# ex1 not all arguments converted during string formatting
# ('014100',)
# ('014130',)
# ex1 not all arguments converted during string formatting
# ('014160',)
# ex1 not all arguments converted during string formatting
# ('014190',)
# ex1 not all arguments converted during string formatting
# ('014200',)
# ex1 not all arguments converted during string formatting
# ('014280',)
# ex1 not all arguments converted during string formatting
# ('014285',)
# ex1 not all arguments converted during string formatting
# ('014440',)
# ex1 not all arguments converted during string formatting
# ('014470',)
# ex1 not all arguments converted during string formatting
# ('014530',)
# ex1 not all arguments converted during string formatting
# ('014570',)
# ex1 not all arguments converted during string formatting
# ('014580',)
# ex1 not all arguments converted during string formatting
# ('014620',)
# ex1 not all arguments converted during string formatting
# ('014680',)
# ex1 not all arguments converted during string formatting
# ('014710',)
# ex1 not all arguments converted during string formatting
# ('014790',)
# ex1 not all arguments converted during string formatting
# ('014820',)
# ex1 not all arguments converted during string formatting
# ('014825',)
# ex1 not all arguments converted during string formatting
# ('014830',)
# ex1 not all arguments converted during string formatting
# ('014910',)
# ex1 not all arguments converted during string formatting
# ('014915',)
# ex1 not all arguments converted during string formatting
# ('014940',)
# ex1 not all arguments converted during string formatting
# ('014970',)
# ex1 not all arguments converted during string formatting
# ('014990',)
# ex1 not all arguments converted during string formatting
# ('015020',)
# ex1 not all arguments converted during string formatting
# ('015230',)
# ex1 not all arguments converted during string formatting
# ('015260',)
# ex1 not all arguments converted during string formatting
# ('015350',)
# ex1 not all arguments converted during string formatting
# ('015360',)
# ex1 not all arguments converted during string formatting
# ('015540',)
# ('015590',)
# ex1 not all arguments converted during string formatting
# ('015710',)
# ex1 not all arguments converted during string formatting
# ('015750',)
# ex1 not all arguments converted during string formatting
# ('015760',)
# ex1 not all arguments converted during string formatting
# ('015860',)
# ex1 not all arguments converted during string formatting
# ('015890',)
# ex1 not all arguments converted during string formatting
# ('016090',)
# ex1 not all arguments converted during string formatting
# ('016100',)
# ex1 not all arguments converted during string formatting
# ('016250',)
# ex1 not all arguments converted during string formatting
# ('016360',)
# ex1 not all arguments converted during string formatting
# ('016380',)
# ex1 not all arguments converted during string formatting
# ('016385',)
# ex1 not all arguments converted during string formatting
# ('016450',)
# ex1 not all arguments converted during string formatting
# ('016580',)
# ex1 not all arguments converted during string formatting
# ('016590',)
# ex1 not all arguments converted during string formatting
# ('016600',)
# ex1 not all arguments converted during string formatting
# ('016610',)
# ex1 not all arguments converted during string formatting
# ('016710',)
# ex1 not all arguments converted during string formatting
# ('016740',)
# ex1 not all arguments converted during string formatting
# ('016790',)
# ex1 not all arguments converted during string formatting
# ('016800',)
# ex1 not all arguments converted during string formatting
# ('016880',)
# ex1 not all arguments converted during string formatting
# ('016920',)
# ex1 not all arguments converted during string formatting
# ('017000',)
# ex1 not all arguments converted during string formatting
# ('017040',)
# ex1 not all arguments converted during string formatting
# ('017180',)
# ex1 not all arguments converted during string formatting
# ('017250',)
# ex1 not all arguments converted during string formatting
# ('017370',)
# ex1 not all arguments converted during string formatting
# ('017390',)
# ex1 not all arguments converted during string formatting
# ('017480',)
# ex1 not all arguments converted during string formatting
# ('017510',)
# ex1 not all arguments converted during string formatting
# ('017550',)
# ex1 not all arguments converted during string formatting
# ('017650',)
# ex1 not all arguments converted during string formatting
# ('017670',)
# ex1 not all arguments converted during string formatting
# ('017800',)
# ex1 not all arguments converted during string formatting
# ('017810',)
# ex1 not all arguments converted during string formatting
# ('017890',)
# ex1 not all arguments converted during string formatting
# ('017900',)
# ex1 not all arguments converted during string formatting
# ('017940',)
# ex1 not all arguments converted during string formatting
# ('017960',)
# ex1 not all arguments converted during string formatting
# ('018000',)
# ex1 not all arguments converted during string formatting
# ('018120',)
# ex1 not all arguments converted during string formatting
# ('018250',)
# ex1 not all arguments converted during string formatting
# ('018260',)
# ex1 not all arguments converted during string formatting
# ('018290',)
# ex1 not all arguments converted during string formatting
# ('018310',)
# ex1 not all arguments converted during string formatting
# ('018470',)
# ex1 not all arguments converted during string formatting
# ('018500',)
# ex1 not all arguments converted during string formatting
# ('018620',)
# ex1 not all arguments converted during string formatting
# ('018670',)
# ex1 not all arguments converted during string formatting
# ('018680',)
# ex1 not all arguments converted during string formatting
# ('018700',)
# ex1 not all arguments converted during string formatting
# ('018880',)
# ex1 not all arguments converted during string formatting
# ('019010',)
# ex1 not all arguments converted during string formatting
# ('019170',)
# ex1 not all arguments converted during string formatting
# ('019175',)
# ex1 not all arguments converted during string formatting
# ('019180',)
# ex1 not all arguments converted during string formatting
# ('019210',)
# ex1 not all arguments converted during string formatting
# ('019440',)
# ex1 not all arguments converted during string formatting
# ('019490',)
# ex1 not all arguments converted during string formatting
# ('019540',)
# ex1 not all arguments converted during string formatting
# ('019550',)
# ex1 not all arguments converted during string formatting
# ('019570',)
# ex1 not all arguments converted during string formatting
# ('019590',)
# ex1 not all arguments converted during string formatting
# ('019660',)
# ex1 not all arguments converted during string formatting
# ('019680',)
# ex1 not all arguments converted during string formatting
# ('019685',)
# ex1 not all arguments converted during string formatting
# ('019770',)
# ex1 not all arguments converted during string formatting
# ('019990',)
# ex1 not all arguments converted during string formatting
# ('020000',)
# ex1 not all arguments converted during string formatting
# ('020120',)
# ex1 not all arguments converted during string formatting
# ('020150',)
# ex1 not all arguments converted during string formatting
# ('020180',)
# ex1 not all arguments converted during string formatting
# ('020400',)
# ex1 not all arguments converted during string formatting
# ('020560',)
# ex1 not all arguments converted during string formatting
# ('020710',)
# ex1 not all arguments converted during string formatting
# ('020760',)
# ex1 not all arguments converted during string formatting
# ('021040',)
# ex1 not all arguments converted during string formatting
# ('021045',)
# ex1 not all arguments converted during string formatting
# ('021050',)
# ex1 not all arguments converted during string formatting
# ('021080',)
# ex1 not all arguments converted during string formatting
# ('021240',)
# ex1 not all arguments converted during string formatting
# ('021320',)
# ex1 not all arguments converted during string formatting
# ('021650',)
# ex1 not all arguments converted during string formatting
# ('021880',)
# ex1 not all arguments converted during string formatting
# ('022100',)
# ex1 not all arguments converted during string formatting
# ('022220',)
# ex1 not all arguments converted during string formatting
# ('023000',)
# ex1 not all arguments converted during string formatting
# ('023150',)
# ex1 not all arguments converted during string formatting
# ('023160',)
# ex1 not all arguments converted during string formatting
# ('023350',)
# ex1 not all arguments converted during string formatting
# ('023410',)
# ex1 not all arguments converted during string formatting
# ('023440',)
# ex1 not all arguments converted during string formatting
# ('023450',)
# ex1 not all arguments converted during string formatting
# ('023460',)
# ex1 not all arguments converted during string formatting
# ('023530',)
# ex1 not all arguments converted during string formatting
# ('023590',)
# ex1 not all arguments converted during string formatting
# ('023600',)
# ex1 not all arguments converted during string formatting
# ('023760',)
# ex1 not all arguments converted during string formatting
# ('023770',)
# ex1 not all arguments converted during string formatting
# ('023790',)
# ex1 not all arguments converted during string formatting
# ('023800',)
# ex1 not all arguments converted during string formatting
# ('023810',)
# ex1 not all arguments converted during string formatting
# ('023900',)
# ex1 not all arguments converted during string formatting
# ('023910',)
# ex1 not all arguments converted during string formatting
# ('023960',)
# ex1 not all arguments converted during string formatting
# ('024060',)
# ex1 not all arguments converted during string formatting
# ('024070',)
# ex1 not all arguments converted during string formatting
# ('024090',)
# ex1 not all arguments converted during string formatting
# ('024110',)
# ex1 not all arguments converted during string formatting
# ('024120',)
# ex1 not all arguments converted during string formatting
# ('024720',)
# ex1 not all arguments converted during string formatting
# ('024740',)
# ex1 not all arguments converted during string formatting
# ('024800',)
# ex1 not all arguments converted during string formatting
# ('024810',)
# ex1 not all arguments converted during string formatting
# ('024840',)
# ex1 not all arguments converted during string formatting
# ('024850',)
# ex1 not all arguments converted during string formatting
# ('024880',)
# ex1 not all arguments converted during string formatting
# ('024890',)
# ex1 not all arguments converted during string formatting
# ('024900',)
# ex1 not all arguments converted during string formatting
# ('024910',)
# ex1 not all arguments converted during string formatting
# ('024940',)
# ex1 not all arguments converted during string formatting
# ('024950',)
# ex1 not all arguments converted during string formatting
# ('025000',)
# ex1 not all arguments converted during string formatting
# ('025320',)
# ex1 not all arguments converted during string formatting
# ('025440',)
# ex1 not all arguments converted during string formatting
# ...
# ('028670',)
# ex1 not all arguments converted during string formatting
# ('029460',)
# ex1 not all arguments converted during string formatting
# ('029480',)
# ex1 not all arguments converted during string formatting
# ('029530',)
# ex1 not all arguments converted during string formatting
# ('029780',)
# ex1 not all arguments converted during string formatting
# ('029960',)
# ex1 not all arguments converted during string formatting
# ('030000',)
# ex1 not all arguments converted during string formatting
# ('030190',)
# ex1 not all arguments converted during string formatting
# ('030200',)
# ex1 not all arguments converted during string formatting
# ('030210',)
# ex1 not all arguments converted during string formatting
# ('030350',)
# ex1 not all arguments converted during string formatting
# ('030520',)
# ex1 not all arguments converted during string formatting
# ('030530',)
# ex1 not all arguments converted during string formatting
# ('030610',)
# ex1 not all arguments converted during string formatting
# ('030720',)
# ex1 not all arguments converted during string formatting
# ('030790',)
# ex1 not all arguments converted during string formatting
# ('030960',)
# ex1 not all arguments converted during string formatting
# ('031310',)
# ex1 not all arguments converted during string formatting
# ('031330',)
# ex1 not all arguments converted during string formatting
# ('031390',)
# ex1 not all arguments converted during string formatting
# ('031430',)
# ex1 not all arguments converted during string formatting
# ('031440',)
# ex1 not all arguments converted during string formatting
# ('031510',)
# ex1 not all arguments converted during string formatting
# ('031820',)
# ex1 not all arguments converted during string formatting
# ('031860',)
# ex1 not all arguments converted during string formatting
# ('031980',)
# ex1 not all arguments converted during string formatting
# ('032080',)
# ex1 not all arguments converted during string formatting
# ('032190',)
# ex1 not all arguments converted during string formatting
# ('032280',)
# ex1 not all arguments converted during string formatting
# ('032300',)
# ex1 not all arguments converted during string formatting
# ('032350',)
# ex1 not all arguments converted during string formatting
# ('032500',)
# ex1 not all arguments converted during string formatting
# ('032540',)
# ex1 not all arguments converted during string formatting
# ('032560',)
# ex1 not all arguments converted during string formatting
# ('032580',)
# ex1 not all arguments converted during string formatting
# ('032620',)
# ex1 not all arguments converted during string formatting
# ('032640',)
# ex1 not all arguments converted during string formatting
# ('032680',)
# ex1 not all arguments converted during string formatting
# ('032685',)
# ex1 not all arguments converted during string formatting
# ('032750',)
# ex1 not all arguments converted during string formatting
# ('032800',)
# ex1 not all arguments converted during string formatting
# ('032820',)
# ex1 not all arguments converted during string formatting
# ('032830',)
# ex1 not all arguments converted during string formatting
# ('032850',)
# ex1 not all arguments converted during string formatting
# ('032860',)
# ex1 not all arguments converted during string formatting
# ('032940',)
# ex1 not all arguments converted during string formatting
# ('032960',)
# ex1 not all arguments converted during string formatting
# ('032980',)
# ex1 not all arguments converted during string formatting
# ('033050',)
# ex1 not all arguments converted during string formatting
# ('033100',)
# ex1 not all arguments converted during string formatting
# ('033130',)
# ex1 not all arguments converted during string formatting
# ('033160',)
# ex1 not all arguments converted during string formatting
# ('033170',)
# ex1 not all arguments converted during string formatting
# ('033180',)
# ex1 not all arguments converted during string formatting
# ('033200',)
# ex1 not all arguments converted during string formatting
# ('033230',)
# ex1 not all arguments converted during string formatting
# ('033240',)
# ex1 not all arguments converted during string formatting
# ('033250',)
# ex1 not all arguments converted during string formatting
# ('033270',)
# ex1 not all arguments converted during string formatting
# ('033290',)
# ex1 not all arguments converted during string formatting
# ('033310',)
# ex1 not all arguments converted during string formatting
# ('033320',)
# ex1 not all arguments converted during string formatting
# ('033340',)
# ('033500',)
# ex1 not all arguments converted during string formatting
# ('033530',)
# ex1 not all arguments converted during string formatting
# ('033540',)
# ex1 not all arguments converted during string formatting
# ('033560',)
# ex1 not all arguments converted during string formatting
# ('033640',)
# ex1 not all arguments converted during string formatting
# ('033780',)
# ex1 not all arguments converted during string formatting
# ('033830',)
# ex1 not all arguments converted during string formatting
# ('033920',)
# ex1 not all arguments converted during string formatting
# ('034020',)
# ex1 not all arguments converted during string formatting
# ('034120',)
# ex1 not all arguments converted during string formatting
# ('034220',)
# ex1 not all arguments converted during string formatting
# ('034230',)
# ex1 not all arguments converted during string formatting
# ('034300',)
# ex1 not all arguments converted during string formatting
# ('034310',)
# ex1 not all arguments converted during string formatting
# ('034590',)
# ex1 not all arguments converted during string formatting
# ('034730',)
# ex1 not all arguments converted during string formatting
# ('03473K',)
# ex1 not all arguments converted during string formatting
# ('034810',)
# ex1 not all arguments converted during string formatting
# ('034830',)
# ex1 not all arguments converted during string formatting
# ('034940',)
# ex1 not all arguments converted during string formatting
# ('034950',)
# ex1 not all arguments converted during string formatting
# ('035000',)
# ex1 not all arguments converted during string formatting
# ('035080',)
# ex1 not all arguments converted during string formatting
# ('035150',)
# ex1 not all arguments converted during string formatting
# ('035200',)
# ex1 not all arguments converted during string formatting
# ('035250',)
# ex1 not all arguments converted during string formatting
# ('035420',)
# ex1 not all arguments converted during string formatting
# ('035460',)
# ex1 not all arguments converted during string formatting
# ('035510',)
# ex1 not all arguments converted during string formatting
# ('035600',)
# ex1 not all arguments converted during string formatting
# ('035610',)
# ex1 not all arguments converted during string formatting
# ('035620',)
# ex1 not all arguments converted during string formatting
# ('035720',)
# ex1 not all arguments converted during string formatting
# ('035760',)
# ex1 not all arguments converted during string formatting
# ('035810',)
# ex1 not all arguments converted during string formatting
# ('035890',)
# ex1 not all arguments converted during string formatting
# ('035900',)
# ex1 not all arguments converted during string formatting
# ('036000',)
# ex1 not all arguments converted during string formatting
# ('036010',)
# ex1 not all arguments converted during string formatting
# ('036030',)
# ex1 not all arguments converted during string formatting
# ('036090',)
# ex1 not all arguments converted during string formatting
# ('036120',)
# ex1 not all arguments converted during string formatting
# ('036170',)
# ex1 not all arguments converted during string formatting
# ('036180',)
# ex1 not all arguments converted during string formatting
# ('036190',)
# ex1 not all arguments converted during string formatting
# ('036200',)
# ex1 not all arguments converted during string formatting
# ('036420',)
# ex1 not all arguments converted during string formatting
# ('036460',)
# ex1 not all arguments converted during string formatting
# ('036480',)
# ex1 not all arguments converted during string formatting
# ('036490',)
# ex1 not all arguments converted during string formatting
# ('036530',)
# ex1 not all arguments converted during string formatting
# ('036540',)
# ex1 not all arguments converted during string formatting
# ('036560',)
# ex1 not all arguments converted during string formatting
# ('036570',)
# ex1 not all arguments converted during string formatting
# ('036580',)
# ex1 not all arguments converted during string formatting
# ('036620',)
# ex1 not all arguments converted during string formatting
# ('036630',)
# ex1 not all arguments converted during string formatting
# ('036640',)
# ex1 not all arguments converted during string formatting
# ('036670',)
# ex1 not all arguments converted during string formatting
# ('036690',)
# ex1 not all arguments converted during string formatting
# ('036710',)
# ex1 not all arguments converted during string formatting
# ('036800',)
# ex1 not all arguments converted during string formatting
# ('036810',)
# ex1 not all arguments converted during string formatting
# ('036830',)
# ex1 not all arguments converted during string formatting
# ('036890',)
# ex1 not all arguments converted during string formatting
# ('036930',)
# ex1 not all arguments converted during string formatting
# ('037030',)
# ex1 not all arguments converted during string formatting
# ('037070',)
# ex1 not all arguments converted during string formatting
# ('037230',)
# ex1 not all arguments converted during string formatting
# ('037270',)
# ex1 not all arguments converted during string formatting
# ('037330',)
# ex1 not all arguments converted during string formatting
# ('037350',)
# ex1 not all arguments converted during string formatting
# ('037370',)
# ex1 not all arguments converted during string formatting
# ('037400',)
# ex1 not all arguments converted during string formatting
# ('037440',)
# ex1 not all arguments converted during string formatting
# ('037460',)
# ex1 not all arguments converted during string formatting
# ('037560',)
# ex1 not all arguments converted during string formatting
# ('037710',)
# ex1 not all arguments converted during string formatting
# ('037760',)
# ex1 not all arguments converted during string formatting
# ('037950',)
# ex1 not all arguments converted during string formatting
# ('038010',)
# ex1 not all arguments converted during string formatting
# ('038060',)
# ex1 not all arguments converted during string formatting
# ('038070',)
# ex1 not all arguments converted during string formatting
# ('038110',)
# ex1 not all arguments converted during string formatting
# ('038290',)
# ex1 not all arguments converted during string formatting
# ('038340',)
# ('038390',)
# ex1 not all arguments converted during string formatting
# ('038460',)
# ex1 not all arguments converted during string formatting
# ('038500',)
# ex1 not all arguments converted during string formatting
# ('038530',)
# ex1 not all arguments converted during string formatting
# ('038540',)
# ex1 not all arguments converted during string formatting
# ('038620',)
# ex1 not all arguments converted during string formatting
# ('038680',)
# ex1 not all arguments converted during string formatting
# ('038870',)
# ex1 not all arguments converted during string formatting
# ('038880',)
# ex1 not all arguments converted during string formatting
# ('038950',)
# ex1 not all arguments converted during string formatting
# ('039010',)
# ex1 not all arguments converted during string formatting
# ('039020',)
# ex1 not all arguments converted during string formatting
# ('039030',)
# ex1 not all arguments converted during string formatting
# ('039130',)
# ex1 not all arguments converted during string formatting
# ('039200',)
# ex1 not all arguments converted during string formatting
# ('039240',)
# ex1 not all arguments converted during string formatting
# ('039290',)
# ex1 not all arguments converted during string formatting
# ('039310',)
# ex1 not all arguments converted during string formatting
# ('039340',)
# ex1 not all arguments converted during string formatting
# ('039420',)
# ex1 not all arguments converted during string formatting
# ('039440',)
# ex1 not all arguments converted during string formatting
# ('039490',)
# ex1 not all arguments converted during string formatting
# ('039560',)
# ex1 not all arguments converted during string formatting
# ('039570',)
# ex1 not all arguments converted during string formatting
# ('039610',)
# ex1 not all arguments converted during string formatting
# ('039740',)
# ex1 not all arguments converted during string formatting
# ('039830',)
# ex1 not all arguments converted during string formatting
# ('039840',)
# ex1 not all arguments converted during string formatting
# ('039860',)
# ex1 not all arguments converted during string formatting
# ('039980',)
# ex1 not all arguments converted during string formatting
# ('040160',)
# ex1 not all arguments converted during string formatting
# ('040300',)
# ex1 not all arguments converted during string formatting
# ('040350',)
# ex1 not all arguments converted during string formatting
# ('040420',)
# ex1 not all arguments converted during string formatting
# ('040610',)
# ex1 not all arguments converted during string formatting
# ('040910',)
# ex1 not all arguments converted during string formatting
# ('041020',)
# ex1 not all arguments converted during string formatting
# ('041140',)
# ex1 not all arguments converted during string formatting
# ('041190',)
# ex1 not all arguments converted during string formatting
# ('041440',)
# ex1 not all arguments converted during string formatting
# ('041460',)
# ex1 not all arguments converted during string formatting
# ('041510',)
# ex1 not all arguments converted during string formatting
# ('041520',)
# ex1 not all arguments converted during string formatting
# ('041590',)
# ex1 not all arguments converted during string formatting
# ('041650',)
# ex1 not all arguments converted during string formatting
# ('041830',)
# ex1 not all arguments converted during string formatting
# ('041910',)
# ex1 not all arguments converted during string formatting
# ('041920',)
# ex1 not all arguments converted during string formatting
# ('041930',)
# ex1 not all arguments converted during string formatting
# ('041960',)
# ex1 not all arguments converted during string formatting
# ('042000',)
# ex1 not all arguments converted during string formatting
# ('042040',)
# ex1 not all arguments converted during string formatting
# ('042110',)
# ex1 not all arguments converted during string formatting
# ('042370',)
# ex1 not all arguments converted during string formatting
# ('042420',)
# ex1 not all arguments converted during string formatting
# ('042500',)
# ex1 not all arguments converted during string formatting
# ('042510',)
# ex1 not all arguments converted during string formatting
# ('042520',)
# ex1 not all arguments converted during string formatting
# ('042600',)
# ex1 not all arguments converted during string formatting
# ('042660',)
# ex1 not all arguments converted during string formatting
# ('042670',)
# ex1 not all arguments converted during string formatting
# ('042700',)
# ex1 not all arguments converted during string formatting
# ('042940',)
# ex1 not all arguments converted during string formatting
# ('043090',)
# ex1 not all arguments converted during string formatting
# ('043100',)
# ex1 not all arguments converted during string formatting
# ('043150',)
# ex1 not all arguments converted during string formatting
# ('043200',)
# ex1 not all arguments converted during string formatting
# ('043220',)
# ex1 not all arguments converted during string formatting
# ('043260',)
# ex1 not all arguments converted during string formatting
# ('043340',)
# ex1 not all arguments converted during string formatting
# ('043360',)
# ex1 not all arguments converted during string formatting
# ('043370',)
# ex1 not all arguments converted during string formatting
# ('043610',)
# ex1 not all arguments converted during string formatting
# ('043650',)
# ex1 not all arguments converted during string formatting
# ('043710',)
# ex1 not all arguments converted during string formatting
# ('043910',)
# ex1 not all arguments converted during string formatting
# ('044060',)
# ex1 not all arguments converted during string formatting
# ('044180',)
# ex1 not all arguments converted during string formatting
# ('044340',)
# ex1 not all arguments converted during string formatting
# ('044380',)
# ex1 not all arguments converted during string formatting
# ('044450',)
# ex1 not all arguments converted during string formatting
# ('044480',)
# ex1 not all arguments converted during string formatting
# ('044490',)
# ('044780',)
# ex1 not all arguments converted during string formatting
# ('044820',)
# ex1 not all arguments converted during string formatting
# ('044960',)
# ex1

# %%
# 상관계수 구하기
import pandas as pd
import pymysql
from sqlalchemy import create_engine
from pykrx import stock
from datetime import datetime

ticker_cap, ticker_fund = {}, {}
periods = ['last_1m', 'last_3m', 'last_6m', 'last_12m']

### Drop correl
db = pymysql.connect(host='192.168.56.100', port=3306, user='root', passwd='test', db='INDEX_DUCK', charset='utf8', cursorclass=pymysql.cursors.DictCursor)
cursor = db.cursor()
dropTableSql = "DROP TABLE correl"
cursor.execute(dropTableSql)
db.commit()
db.close()

### Calculate correl 
for period in periods:
  try:
    # db = pymysql.connect(host='192.168.56.100', port=3306, user='root', passwd='root', db='INDEX_DUCK', charset='utf8', cursorclass=pymysql.cursors.DictCursor)
    db = pymysql.connect(host='192.168.56.100', port=3306, user='root', passwd='test', db='INDEX_DUCK', charset='utf8', cursorclass=pymysql.cursors.DictCursor)
    cursor = db.cursor()

    getTickersSql = "SELECT DISTINCT ticker FROM %s" % (period)
    cursor.execute(getTickersSql)
    tickers = cursor.fetchall()
    for ticker in tickers:
      t = ticker['ticker']
      print(t)
      getTickerInfoSql = "SELECT * FROM %s WHERE ticker = '%s'" % (period, t)
      cursor.execute(getTickerInfoSql)
      df = pd.DataFrame(cursor.fetchall())
      name = df.loc()[:, 'name'].iloc[0]
      if len(df) < 1:
        continue

      corrDf = df.corr().loc()[:, ['insVolCum', 'etcVolCum', 'indVolCum', 'forVolCum', 'insAmtCum', 'etcAmtCum', 'indAmtCum', 'forAmtCum']].iloc[:1]
      corrDf.insert(0, 'ticker', t)
      corrDf.insert(1, 'name', name)
      corrDf.insert(2, 'period', period)
      try:
        # write_connection = create_engine('mysql+pymysql://root:root@192.168.56.100:3306/INDEX_DUCK', encoding='utf-8')
        write_connection = create_engine('mysql+pymysql://root:test@192.168.56.100:3306/INDEX_DUCK', encoding='utf-8', pool_pre_ping=True).connect()
        corrDf.to_sql(name="correl", con=write_connection, if_exists='append', index=False)
      except Exception as ex1:
        print('ex1', ex1)
        pass
      finally:
        write_connection.close()
  except Exception as ex2:
    print('ex2', ex2)
    db.close()  
    pass

# %%
# 티커 별 정보 셋팅
from sqlalchemy import create_engine
import pymysql
import pandas as pd
from pykrx import stock
import time
from openpyxl import load_workbook
from datetime import datetime, timedelta

### Drop stocks_info
db = pymysql.connect(host='192.168.56.100', port=3306, user='root', passwd='test', db='INDEX_DUCK', charset='utf8', cursorclass=pymysql.cursors.DictCursor)
cursor = db.cursor()
dropTableSql = "DROP TABLE stocks_info"
cursor.execute(dropTableSql)
db.commit()
db.close()

try:
  ticker_name, ticker_cap, ticker_fund = {}, {}, {}

  capDf = stock.get_market_cap_by_ticker(str(datetime.now().date()).replace('-', '')).loc[:, '시가총액']
  fundDf = stock.get_market_fundamental_by_ticker(str(datetime.now().date()).replace('-', ''), market="ALL")
  for ticker in capDf.index:
    ticker_cap[ticker] = capDf.loc[ticker]
  for ticker in fundDf.index:
    ticker_fund[ticker] = list(fundDf.loc[ticker])

  for ticker in stock.get_market_ticker_list():
    name = stock.get_market_ticker_name(ticker)
    ticker_name[ticker] = [name, 'KOSPI']
    
  for ticker in stock.get_market_ticker_list(market='KOSDAQ'):
    name = stock.get_market_ticker_name(ticker)
    ticker_name[ticker] = [name, 'KOSDAQ']

  for ticker in ticker_name:
    if ticker not in capDf.index or ticker not in fundDf.index:
      continue

    tickerInfo = [ticker]
    tickerInfo += ticker_name[ticker]
    tickerInfo.append(ticker_cap[ticker])
    tickerInfo += ticker_fund[ticker]

    tickerInfoDf = pd.DataFrame([tickerInfo], columns = ['ticker', 'name', 'market', 'cap', 'bps', 'per', 'pbr', 'eps', 'divi', 'dps'])
    try:
      # write_connection = create_engine('mysql+pymysql://root:test@192.168.56.100:3306/INDEX_DUCK', encoding='utf-8', pool_pre_ping=True).connect()
      write_connection = create_engine('mysql+pymysql://root:root@192.168.56.100:3306/INDEX_DUCK', encoding='utf-8', pool_pre_ping=True).connect()
      tickerInfoDf.to_sql(name="stocks_info", con=write_connection, if_exists='append', index=False)
    except Exception as ex1:
      print('ex1', ex1)
      pass
    finally:
      write_connection.close()
except Exception as ex:
  print(ex)

# %%
# # 이동평균선 구하기
# import pandas as pd
# import pymysql
# from sqlalchemy import create_engine
# from pykrx import stock
# from datetime import datetime

# ticker_cap = {}

# try:
#   # db = pymysql.connect(host='192.168.56.100', port=3306, user='root', passwd='root', db='INDEX_DUCK', charset='utf8', cursorclass=pymysql.cursors.DictCursor)
#   db = pymysql.connect(host='192.168.56.100', port=3306, user='root', passwd='test', db='INDEX_DUCK', charset='utf8', cursorclass=pymysql.cursors.DictCursor)
#   cursor = db.cursor()

#   getTickersSql = "SELECT DISTINCT ticker FROM stocks"
#   cursor.execute(getTickersSql)
#   tickers = cursor.fetchall()
#   db.close()  
#   for ticker in tickers:
#     t = ticker['ticker']
#     print(t)
#     db = pymysql.connect(host='192.168.56.100', port=3306, user='root', passwd='test', db='INDEX_DUCK', charset='utf8', cursorclass=pymysql.cursors.DictCursor)
#     cursor = db.cursor()

#     getTickerInfoSql = "SELECT * FROM %s WHERE ticker = '%s'" % (period, t)
#     cursor.execute(getTickerInfoSql)
#     df = pd.DataFrame(cursor.fetchall())
#     name = df.loc()[:, 'name'].iloc[0]
#     if len(df) < 1:
#       continue

#     corrDf = df.corr().loc()[:, ['insVolCum', 'etcVolCum', 'indVolCum', 'forVolCum', 'insAmtCum', 'etcAmtCum', 'indAmtCum', 'forAmtCum']].iloc[:1]
#     corrDf.insert(0, 'ticker', ticker['ticker'])
#     corrDf.insert(1, 'name', name)
#     corrDf.insert(2, 'period', period)
#     corrDf.insert(3, 'cap', ticker_cap[ticker['ticker']])
#     try:
#       # write_connection = create_engine('mysql+pymysql://root:root@192.168.56.100:3306/INDEX_DUCK', encoding='utf-8')
#       write_connection = create_engine('mysql+pymysql://root:test@192.168.56.100:3306/INDEX_DUCK', encoding='utf-8', pool_pre_ping=True).connect()
#       corrDf.to_sql(name="correl", con=write_connection, if_exists='append', index=False)
#     except Exception as ex1:
#       print('ex1', ex1)
#       pass
#     finally:
#       db.close()  
#       conn.close()
# except Exception as ex2:
#   print('ex2', ex2)
#   pass
